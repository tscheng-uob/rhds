# %%
library(here)
readRenviron(here("config.env"))
resultsdir <- Sys.getenv("resultsdir")
resultsdir
# Out:
# Warning message in readRenviron(here("config.env")):
# “file '/users/home/user5/config.env' cannot be opened for reading”
# [1] ""
